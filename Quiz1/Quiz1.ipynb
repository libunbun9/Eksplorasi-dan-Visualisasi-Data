# %%
# Quiz 2
# Eksplorisasi dan Visualisasi Data

# %%
# install "pandas" package
#pip install pandas

# %%
# import "pandas" package and set the name as "pd"
import pandas as pd

# %%
# import fire case in Jakarta from 2018
# Source : Satu Data Indonesia
data_kebakaran = pd.read_csv(r"C:\Users\yippi\Downloads\kebakaran_kuis2.csv")

# %%
# call the dataset
data_kebakaran
# Out:
#        _id              tanggal jenis_kejadian_bencana       keterangan_jkb  \
# 0        1  2018-02-01T00:00:00           Penyelamatan   Pengendalian Hewan
# 1        2  2018-02-01T00:00:00              Kebakaran    Bencana Kebakaran
# 2        3  2018-02-01T00:00:00           Penyelamatan   Pengendalian Hewan
# 3        4  2018-02-01T00:00:00           Penyelamatan        Pohon Tumbang
# 4        5  2018-02-01T00:00:00              Kebakaran    Bencana Kebakaran
# ...    ...                  ...                    ...                  ...
# 3886  3887  2018-01-31T00:00:00              Kebakaran    Bencana Kebakaran
# 3887  3888  2018-01-31T00:00:00        Bantuan Operasi  Kesiagaan/Penjagaan
# 3888  3889  2018-01-31T00:00:00        Bantuan Operasi  Kesiagaan/Penjagaan
# 3889  3890  2018-01-03T00:00:00           Penyelamatan   Pengendalian Hewan
# 3890  3891  2018-01-06T00:00:00           Penyelamatan   Pengendalian Hewan
#
# ...

# %%
# subset data using iloc
data_loc1 = pd.DataFrame(data_kebakaran.iloc[range(0,10),[0,3]])
data_loc1
# Out:
#    _id      keterangan_jkb
# 0    1  Pengendalian Hewan
# 1    2   Bencana Kebakaran
# 2    3  Pengendalian Hewan
# 3    4       Pohon Tumbang
# 4    5   Bencana Kebakaran
# 5    6  Pengendalian Hewan
# 6    7   Bencana Kebakaran
# 7    8  Pengendalian Hewan
# 8    9   Bencana Kebakaran
# 9   10  Pengendalian Hewan

# %%
# subset data using iloc 
data_loc2 = data_kebakaran.iloc[range(0,10),[0,10]]
data_loc2
# Out:
#    _id taksiran_kerugian
# 0    1                 0
# 1    2         150000000
# 2    3                 0
# 3    4                 0
# 4    5        1215000000
# 5    6                 0
# 6    7          25000000
# 7    8                 0
# 8    9           5000000
# 9   10                 0

# %%
# # merge data first and second iloc from previous code, merge by "_id" index.

# %%
merge_datailoc = pd.merge(data_loc1,data_loc2, on ="_id")

# %%
# call merged dataset
merge_datailoc
# Out:
#    _id      keterangan_jkb taksiran_kerugian
# 0    1  Pengendalian Hewan                 0
# 1    2   Bencana Kebakaran         150000000
# 2    3  Pengendalian Hewan                 0
# 3    4       Pohon Tumbang                 0
# 4    5   Bencana Kebakaran        1215000000
# 5    6  Pengendalian Hewan                 0
# 6    7   Bencana Kebakaran          25000000
# 7    8  Pengendalian Hewan                 0
# 8    9   Bencana Kebakaran           5000000
# 9   10  Pengendalian Hewan                 0

# %%
# export merged dataset to csv and include column name above.
merge_datailoc.to_csv("test_merge_iloc.csv", index=True)

# %%
# Alicia Arifin
# Statistics Matana University
